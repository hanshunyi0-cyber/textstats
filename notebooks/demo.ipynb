# %% [markdown]
# <a href="https://colab.research.google.com/github/hanshunyi0-cyber/textstats/blob/main/notebooks/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q git+https://github.com/hanshunyi0-cyber/textstats
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import textstats

print(textstats.word_count("the quick brown fox"))    #  4
print(textstats.longest_word("the quick brown fox"))  #  quick
print(textstats.char_frequencies("Aa b"))        #  {'a': 2, 'b': 1}
# Out:
# 4
# quick
# {'a': 2, 'b': 1}
